# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = yf.download('GOOG','2020-10-01','2021-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
