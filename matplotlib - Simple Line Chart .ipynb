# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
stock = pd.read_csv('GOOG.csv')
stock
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-03-26  1111.800049  1169.969971  1093.530029  1161.750000
# 1    2020-03-27  1125.670044  1150.670044  1105.910034  1110.709961
# 2    2020-03-30  1125.040039  1151.630005  1096.479980  1146.819946
# 3    2020-03-31  1147.300049  1175.310059  1138.140015  1162.810059
# 4    2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# ..          ...          ...          ...          ...          ...
# 247  2021-03-19  2042.050049  2053.100098  2017.680054  2043.199951
# 248  2021-03-22  2041.839966  2057.989990  2026.069946  2038.589966
# 249  2021-03-23  2051.699951  2072.302002  2039.219971  2052.959961
# 250  2021-03-24  2065.370117  2078.209961  2041.555054  2045.060059
# 251  2021-03-25  2044.810059  2058.709961  2010.729980  2044.359985
#
#        Adj Close   Volume
# 0    1161.750000  3571700
# 1    1110.709961  3208500
# 2    1146.819946  2574100
# 3    1162.810059  2486400
# ...

# %%
indexed_stock = stock.set_index('Date')

# %%
ts = indexed_stock[['High']]

# %%
ts
# Out:
#                    High
# Date
# 2020-03-26  1169.969971
# 2020-03-27  1150.670044
# 2020-03-30  1151.630005
# 2020-03-31  1175.310059
# 2020-04-01  1129.689941
# ...                 ...
# 2021-03-19  2053.100098
# 2021-03-22  2057.989990
# 2021-03-23  2072.302002
# 2021-03-24  2078.209961
# 2021-03-25  2058.709961
#
# [252 rows x 1 columns]

# %%
plt.style.use('seaborn')
plt.plot(ts)

# %%
plt.show()

# %%
ts_low = indexed_stock[['Low']]

# %%
ts_low
# Out:
#                     Low
# Date
# 2020-03-26  1093.530029
# 2020-03-27  1105.910034
# 2020-03-30  1096.479980
# 2020-03-31  1138.140015
# 2020-04-01  1097.449951
# ...                 ...
# 2021-03-19  2017.680054
# 2021-03-22  2026.069946
# 2021-03-23  2039.219971
# 2021-03-24  2041.555054
# 2021-03-25  2010.729980
#
# [252 rows x 1 columns]

# %%
fig, ax = plt.subplots()
ax.plot(ts, c = 'blue')
ax.plot(ts_low, c = 'black')
plt.show()
